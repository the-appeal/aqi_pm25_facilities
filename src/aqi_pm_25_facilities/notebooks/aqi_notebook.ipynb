# %%
import math

import geopandas as gpd
import pandas as pd
import requests

# %% [markdown]
# Monitoring site documentation: https://docs.airnowapi.org/docs/MonitoringSiteFactSheet.pdf

# %%
monitoring_site_col_names = [
    "AQSID", "parameter_name", "site_code", "site_name", "status",
    "agency_id", "agency_name", "epa_region", "latitude", "longitude",
    "elevation", "gmt_offset", "country_code", "msa_code", "msa_name",
    "state_code", "state_name", "county_code", "county_name"
]

# %%
monitoring_sites = pd.read_csv(
    "../data/source/monitoring_site_locations.dat", 
    sep="|", 
    encoding="latin",
)
monitoring_sites.head()
# Out:
#    060670006  PM10  0006  Arden Arcade - Del Paso Manor  Active  CA1  \
# 0  060670006   NO2  0006  Arden Arcade - Del Paso Manor  Active  CA1
# 1  060670006    WD  0006  Arden Arcade - Del Paso Manor  Active  CA1
# 2  060670006   SO2  0006  Arden Arcade - Del Paso Manor  Active  CA1
# 3  060670006    BC  0006  Arden Arcade - Del Paso Manor  Active  CA1
# 4  060670006  RHUM  0006  Arden Arcade - Del Paso Manor  Active  CA1
#
#    Sacramento Metro. AQMD  R9  38.613804  -121.368007  ...  Unnamed: 13  \
# 0  Sacramento Metro. AQMD  R9  38.613804  -121.368007  ...          NaN
# 1  Sacramento Metro. AQMD  R9  38.613804  -121.368007  ...          NaN
# 2  Sacramento Metro. AQMD  R9  38.613804  -121.368007  ...          NaN
# 3  Sacramento Metro. AQMD  R9  38.613804  -121.368007  ...          NaN
# 4  Sacramento Metro. AQMD  R9  38.613804  -121.368007  ...          NaN
#
#    Unnamed: 14    40900   Sacramento--Arden-Arcade--Roseville, CA   06  CA  \
# 0          NaN  40900.0   Sacramento--Arden-Arcade--Roseville, CA   06  CA
# 1          NaN  40900.0   Sacramento--Arden-Arcade--Roseville, CA   06  CA
# 2          NaN  40900.0   Sacramento--Arden-Arcade--Roseville, CA   06  CA
# 3          NaN  40900.0   Sacramento--Arden-Arcade--Roseville, CA   06  CA
# 4          NaN  40900.0   Sacramento--Arden-Arcade--Roseville, CA   06  CA
#
#    067  SACRAMENTO Unnamed: 21 Unnamed: 22
# 0  067  SACRAMENTO         NaN         NaN
# 1  067  SACRAMENTO         NaN         NaN
# 2  067  SACRAMENTO         NaN         NaN
# 3  067  SACRAMENTO         NaN         NaN
# 4  067  SACRAMENTO         NaN         NaN
#
# [5 rows x 23 columns]

# %% [markdown]
# It's unclear why pandas added four extra empty columns, but we should get rid of them and add the correct column names. This code drops the first row, but it's not relevant for our purposes.

# %%
monitoring_sites = monitoring_sites.drop(
    columns=[
        "Unnamed: 13", "Unnamed: 14",
        "Unnamed: 21", "Unnamed: 22"
    ]
)
monitoring_sites.columns = monitoring_site_col_names
monitoring_sites.head()
# Out:
#        AQSID parameter_name site_code                      site_name  status  \
# 0  060670006            NO2      0006  Arden Arcade - Del Paso Manor  Active
# 1  060670006             WD      0006  Arden Arcade - Del Paso Manor  Active
# 2  060670006            SO2      0006  Arden Arcade - Del Paso Manor  Active
# 3  060670006             BC      0006  Arden Arcade - Del Paso Manor  Active
# 4  060670006           RHUM      0006  Arden Arcade - Del Paso Manor  Active
#
#   agency_id             agency_name epa_region   latitude   longitude  \
# 0       CA1  Sacramento Metro. AQMD         R9  38.613804 -121.368007
# 1       CA1  Sacramento Metro. AQMD         R9  38.613804 -121.368007
# 2       CA1  Sacramento Metro. AQMD         R9  38.613804 -121.368007
# 3       CA1  Sacramento Metro. AQMD         R9  38.613804 -121.368007
# 4       CA1  Sacramento Metro. AQMD         R9  38.613804 -121.368007
#
#    elevation  gmt_offset country_code  msa_code  \
# 0       25.3        -8.0           US   40900.0
# 1       25.3        -8.0           US   40900.0
# 2       25.3        -8.0           US   40900.0
# 3       25.3        -8.0           US   40900.0
# 4       25.3        -8.0           US   40900.0
#
#                                     msa_name state_code state_name  \
# 0   Sacramento--Arden-Arcade--Roseville, CA          06         CA
# 1   Sacramento--Arden-Arcade--Roseville, CA          06         CA
# 2   Sacramento--Arden-Arcade--Roseville, CA          06         CA
# 3   Sacramento--Arden-Arcade--Roseville, CA          06         CA
# 4   Sacramento--Arden-Arcade--Roseville, CA          06         CA
#
#   county_code county_name
# 0         067  SACRAMENTO
# 1         067  SACRAMENTO
# 2         067  SACRAMENTO
# 3         067  SACRAMENTO
# 4         067  SACRAMENTO

# %% [markdown]
# Filter sites to states of interest and their neighbors:

# %%
midatlantic_monitoring_sites = monitoring_sites.loc[
    lambda df: (
        (
            df["state_name"]
            .isin(
                [
                    "MA", "CT", "VT", "NY", "NJ", 
                    "PA", "OH", "MD", "DE", "WV",
                ]
            )
        )
        & (df["parameter_name"] == "PM2.5")
    )
]

# %% [markdown]
# Read in hourly observations:

# %%
hourly_obs = pd.read_csv("../data/source/hourly_obs.csv", na_values="-999")
hourly_obs.head()
# Out:
#             site    site_id    0    1    2    3    4    5    6    7  ...   14  \
# 0  CHARLOTTETOWN  000020104  0.7  0.6  0.4  0.6  0.8  1.1  1.2  1.1  ...  1.2
# 1  CHARLOTTETOWN  000020104    G    G    G    G    G    G    G    G  ...    G
# 2     WELLINGTON  000020301  3.3  1.5  0.9  1.2  0.7  0.9  1.7  1.4  ...  2.4
# 3     WELLINGTON  000020301    G    G    G    G    G    G    G    G  ...    G
# 4    SOUTHAMPTON  000020401  1.6  1.3  1.0  0.9  0.9  1.5  1.5  1.5  ...  2.4
#
#     15   16   17   18   19   20   21   22   23
# 0  1.7  2.5  3.3  3.2  3.6  4.3  3.9  3.7  3.6
# 1    G    G    G    G    G    G    G    G    G
# 2  2.9  2.9  3.0  3.3  3.7  3.7  3.6  3.5  3.8
# 3    G    G    G    G    G    G    G    G    G
# 4  4.0  4.7  5.8  7.3  7.4  7.0  6.4  6.7  5.6
#
# [5 rows x 26 columns]

# %% [markdown]
# Drop the non-data rows:

# %%
hourly_obs = hourly_obs.iloc[::2].copy()

# %% [markdown]
# Drop empty rows:

# %%
hourly_obs = hourly_obs.dropna()

# %% [markdown]
# Convert the observations to AQI values using the EPA's formula:
# $$ I_{p} = \frac{I_{Hi} - I_{Lo}}{BP_{Hi} - BP_{Lo}}(C_{p} - BP_{Lo}) + I_{Lo}$$
#
# Where:
# - $ I_{p} $: The index for pollutant $ p $
# - $ C_{p} $: The truncated concentration for pollutant $ p $
# - $ BP_{Hi} $: The concentration breakpoint higher than $ C_{p} $
# - $ BP_{Lo} $: The concentration breakpoint lower than $ C_{p} $
# - $ I_{Hi} $: The index value corresponding to $ BP_{Hi} $
# - $ I_{Lo} $: The index value corresponding to $ BP_{Lo} $
#
# In the case of PM2.5, this gives us the following function:

# %%
def calc_aqi(concentration):
    if concentration == -999.0:  # missing data
        return -999
    elif concentration <= 12.0:
        aqi = (50 - 0)/(12.0 - 0) * (concentration - 0)
    elif concentration <= 35.4:
        aqi = (100 - 50)/(35.4 - 12.1) * (concentration - 12.1) + 50
    elif concentration <= 55.4:
        aqi = (150 - 100)/(55.4 - 35.5) * (concentration - 35.5) + 100
    elif concentration <= 150.4:
        aqi = (200 - 150)/(150.4 - 55.5) * (concentration - 55.5) + 150
    elif concentration <= 250.4:
        aqi = (300 - 200)/(250.4-150.5) * (concentration - 150.5) + 200
    elif concentration <= 500.4:
        aqi = (500 - 300)/(500.4 - 250.5) * (concentration - 250.5) + 300 
    else:
        aqi = 501  # It's off the charts!
    return int(aqi // 1)

# %%
hourly_obs.loc[:, '0':'23'] = hourly_obs.loc[:, '0':'23'].applymap(float).applymap(calc_aqi)

# %% [markdown]
# Calculate the peak observation at each site:

# %%
hourly_obs["peak"] = hourly_obs.loc[:, '0':'23'].T.max()

# %% [markdown]
# Calculate the average observation at each site:

# %%
hourly_obs["average"] = hourly_obs.loc[:, '0':'23'].T.mean()

# %%
hourly_obs.head()
# Out:
#                    site    site_id   0   1   2   3   4   5   6   7  ...  16  \
# 0         CHARLOTTETOWN  000020104   2   2   1   2   3   4   5   4  ...  10
# 2            WELLINGTON  000020301  13   6   3   5   2   3   7   5  ...  12
# 4           SOUTHAMPTON  000020401   6   5   4   3   3   6   6   6  ...  19
# 22            Longueuil  000050119  66  60  57  45  29  31  54  56  ...  15
# 24  Brossard - Parc Sor  000050122  75  59  56  51  29  30  50  57  ...  16
#
#     17  18  19  20  21  22  23 peak    average
# 0   13  13  15  17  16  15  15   17   7.833333
# 2   12  13  15  15  15  14  15   15   8.708333
# 4   24  30  30  29  26  27  23   30  12.833333
# 22  14  16  18  16  13  11  13   66  29.500000
# 24  14  15  18  18  19  13  13   75  31.333333
#
# [5 rows x 28 columns]

# %% [markdown]
# Combine the lat/long data with the peak AQI data:

# %%
peak_site_data = (
    midatlantic_monitoring_sites
    .merge(
        hourly_obs,
        left_on="AQSID",
        right_on="site_id",
    )
    .set_index("site_id")
)[["site_name", "state_name", "county_name", "latitude", "longitude", "peak", "average"]]
peak_site_data.head()
# Out:
#                      site_name state_name county_name   latitude  longitude  \
# site_id
# 390030009                 Lima         OH       ALLEN  40.771000 -84.053900
# 250250042     Boston - Roxbury         MA     SUFFOLK  42.329399 -71.082497
# 250095005            Haverhill         MA       ESSEX  42.770800 -71.102800
# 420070014         Beaver Falls         PA      BEAVER  40.747799 -80.316704
# 840250030008      PittsfieldES         MA   BERKSHIRE  42.452299 -73.239648
#
#              peak     average
# site_id
# 390030009     154  103.416667
# 250250042      88   50.416667
# 250095005      92   41.583333
# 420070014     153  101.083333
# 840250030008  190  161.250000

# %% [markdown]
# Load facility data:

# %%
facilities = gpd.read_file("../data/source/prison_boundaries.geojson")
facilities.head()
# Out:
#    FID FACILITYID                                      NAME  \
# 0    1   10002798   MIDLAND COUNTY CENTRAL DETENTION CENTER
# 1    2   10002796  BARBARA CULVER JUVENILE DETENTION CENTER
# 2    3   10002836                   SAN JACINTO COUNTY JAIL
# 3    4   10003033               YELLOW MEDICINE COUNTY JAIL
# 4    5   10006288     NMJC THIEF RIVER FALLS SATELLITE HOME
#
#                 ADDRESS               CITY STATE    ZIP  ZIP4       TELEPHONE  \
# 0         400 S MAIN ST            MIDLAND    TX  79701  -999  (432) 688-4745
# 1      3800 N LAMESA RD            MIDLAND    TX  79701  -999  (432) 688-4541
# 2        75 W CEDAR AVE         COLDSPRING    TX  77331  -999  (936) 653-4367
# 3        415 9TH AVENUE      GRANITE FALLS    MN  56241  -999  (320) 313-3049
# 4  118 N. SPRUCE AVENUE  THIEF RIVER FALLS    MN  56701  -999  (218) 681-3484
#
#      TYPE  ... CAPACITY  SHAPE_Leng                                GlobalID  \
# 0  COUNTY  ...    498.0    0.007275  {86DE7B8A-37D4-4D99-984B-D70D2B8C474F}
# 1  COUNTY  ...     24.0    0.004645  {1C1E4C11-3209-4E90-85C7-957AE58CEB3C}
# 2  COUNTY  ...    144.0    0.002327  {0764FA0C-E415-4F31-95AB-751C895E6CCF}
# 3  COUNTY  ...     36.0    0.002272  {9A789E0C-3A99-44D7-A17C-3F0C940DC400}
# 4   LOCAL  ...      5.0    0.000644  {A4CD4104-0496-45C8-B09B-FC49557098D0}
#
#                CreationDate        Creator                  EditDate  \
# 0 2022-01-07 15:27:25+00:00  HostedByHIFLD 2022-01-07 15:27:25+00:00
# 1 2022-01-07 15:27:25+00:00  HostedByHIFLD 2022-01-07 15:27:25+00:00
# 2 2022-01-07 15:27:25+00:00  HostedByHIFLD 2022-01-07 15:27:25+00:00
# 3 2022-01-07 15:27:25+00:00  HostedByHIFLD 2022-01-07 15:27:25+00:00
# 4 2022-01-07 15:27:25+00:00  HostedByHIFLD 2022-01-07 15:27:25+00:00
#
#           Editor SHAPE_Length    SHAPE_Area  \
# 0  HostedByHIFLD     0.007275  2.579058e-06
# 1  HostedByHIFLD     0.004645  9.897645e-07
# 2  HostedByHIFLD     0.002327  3.075715e-07
# 3  HostedByHIFLD     0.002272  1.900107e-07
# 4  HostedByHIFLD     0.000644  2.457488e-08
#
#                                             geometry
# 0  MULTIPOLYGON (((-102.07687 31.99381, -102.0744...
# 1  MULTIPOLYGON (((-102.07655 32.03859, -102.0762...
# 2  MULTIPOLYGON (((-95.12992 30.59128, -95.12955 ...
# 3  MULTIPOLYGON (((-95.54458 44.80976, -95.54434 ...
# 4  MULTIPOLYGON (((-96.16240 48.11734, -96.16221 ...
#
# [5 rows x 33 columns]

# %% [markdown]
# Filter to open facilities in our states of interest:

# %%
facilities_midatlantic = (
    facilities.loc[
        lambda df: (
            df["STATE"].isin(["NY", "NJ", "PA", "DE"])
            & df["STATUS"].str.match("OPEN")
        )
    ]
    .copy()
    .drop_duplicates()
)

# %% [markdown]
# Find the centroid of each facility (we can ignore this warning, because we're just trying to find the nearest monitoring site, and this won't really matter for that):

# %%
facilities_midatlantic["centroid"] = (
    facilities_midatlantic["geometry"]
    .centroid
)
# Out:
# /tmp/ipykernel_9347/1775512362.py:3: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   .centroid

# %%
def distance(point, lat, long):
    """Calculate distance using the Haversine formula."""
    lat_1 = math.radians(point.y)
    lat_2 = math.radians(lat)
    lon_1 = math.radians(point.x)
    lon_2 = math.radians(long)
    d_lat = lat_1 - lat_2
    d_lon = lon_1 - lon_2
    alpha = (
        math.sin(d_lat / 2)**2 
        + math.cos(lat_1) 
        * math.cos(lat_2) 
        * math.sin(d_lon / 2)**2
    )
    radius = 3958.8  # radius of earth in miles
    return (
        2
        * radius
        * math.atan2(math.sqrt(alpha), math.sqrt(1 - alpha))
    )

# %% [markdown]
# Find the nearest monitoring site for each facility (using a horrifically inefficient algorithm, but the data is small enough that we don't really mind):

# %%
def dist_to_nearest_site(point, site_data):
    return site_data.apply(
        lambda x: distance(point, x["latitude"], x["longitude"]), axis=1
    ).min()

# %%
def nearest_site(point, site_data):
    nearest_site_dist = dist_to_nearest_site(point, site_data)
    if nearest_site_dist > 25:
        return pd.NA
    return site_data.assign(
        dist=site_data.apply(
            lambda x: distance(
                point,
                x["latitude"],
                x["longitude"],
            ),
            axis=1
        )
    ).loc[lambda df: df["dist"] == df["dist"].min()].index[0]

# %%
facilities_midatlantic["nearest_site"] = (
    facilities_midatlantic["centroid"]
    .map(lambda x: nearest_site(x, peak_site_data.dropna()))
)

# %%
joined_data = (
    facilities_midatlantic
    .dropna()
    .merge(
        peak_site_data.reset_index(),
        left_on="nearest_site",
        right_on="site_id",
    )
    .rename(
        columns={
            "FACILITYID": "facility_id",
            "NAME": "facility_name",
            "ADDRESS": "facility_address",
            "CITY": "facility_city",
            "STATE": "facility_state",
            "ZIP": "facility_zip",
            "TYPE": "facility_type",
            "SECURELVL": "facility_security_level",
            "CAPACITY": "facility_capacity",
            "STATUS": "facility_status",
            "SOURCE": "facility_data_source",
            "CreationDate": "facility_data_source_date",
            "EditDate": "facility_data_edit_date",
            "site_name": "monitoring_site_name",
            "state_name": "monitoring_site_state",
            "county_name": "monitoring_site_county",
            "latitude": "monitoring_site_latitude",
            "longitude": "monitoring_site_longitude",
            "peak": "peak_pm25_aqi",
            "average": "mean_pm25_aqi",
        }
    )
    .drop_duplicates()
    .set_index("facility_id")
).assign(
    facility_latitude=lambda df: df["centroid"].map(lambda x: x.y),
    facility_longitude=lambda df: df["centroid"].map(lambda x: x.x),
)[
    [
        "facility_name", "facility_address", "facility_city",
        "facility_state", "facility_zip", "facility_latitude",
        "facility_longitude", "facility_type",
        "facility_security_level", "facility_capacity",
        "facility_status", "facility_data_source",
        "facility_data_source_date", "facility_data_edit_date", 
        "monitoring_site_name", "monitoring_site_state", 
        "monitoring_site_county", "monitoring_site_latitude",
        "monitoring_site_longitude", "peak_pm25_aqi", 
        "mean_pm25_aqi", "geometry",
    ]
]

# %% [markdown]
# Number of facilities above 200:

# %%
joined_data.loc[
    lambda df: df["peak_pm25_aqi"] > 200
]
# Out:
#                                     facility_name        facility_address  \
# facility_id
# 10005221       WAYNE COUNTY CORRECTIONAL FACILITY         44 MID-WAYNE DR
# 10005223                       MINSEC OF SCRANTON           539 LINDEN ST
# 10003049                 LACKAWANNA COUNTY PRISON   1371 N WASHINGTON AVE
# 10003059                            PA CHILD CARE          701 SATHERS DR
# 10003047                              SCI WAYMART          11 FAIRVIEW DR
# ...                                           ...                     ...
# 10003117                              SCI CHESTER      500 EAST FOURTH ST
# 10000708     SUSSEX VIOLATION OF PROBATION CENTER       23207 DUPONT BLVD
# 10000706      SUSSEX COMMUNITY CORRECTIONS CENTER       23207 DUPONT BLVD
# 10000707          SUSSEX CORRECTIONAL INSTITUTION       23203 DUPONT BLVD
# 10000705         STEVENSON HOUSE DETENTION CENTER  750 N DUPONT BOULEVARD
#
#                  facility_city facility_state facility_zip  facility_latitude  \
# facility_id
# 10005221             HONESDALE             PA        18431          41.548698
# 10005223              SCRANTON             PA        18503          41.408550
# 10003049              SCRANTON             PA        18509          41.422658
# 10003059     PITTSTON TOWNSHIP             PA        18640          41.312296
# 10003047               WAYMART             PA        18472          41.574452
# ...                        ...            ...          ...                ...
# 10003117               CHESTER             PA        19013          39.851245
# 10000708            GEORGETOWN             DE        19947          38.657549
# 10000706            GEORGETOWN             DE        19947          38.658484
# 10000707            GEORGETOWN             DE        19947          38.660047
# 10000705               MILFORD             DE        19963          38.918776
#
#              facility_longitude  facility_type facility_security_level  \
# facility_id
# 10005221             -75.208834         COUNTY           NOT AVAILABLE
# 10005223             -75.661082          LOCAL           NOT AVAILABLE
# 10003049             -75.648372         COUNTY                 MAXIMUM
# 10003059             -75.725906  NOT AVAILABLE                JUVENILE
# 10003047             -75.429367          STATE                 MAXIMUM
# ...                         ...            ...                     ...
# 10003117             -75.351338          STATE                  MEDIUM
# 10000708             -75.368626          STATE           NOT AVAILABLE
# 10000706             -75.371968          STATE           NOT AVAILABLE
# 10000707             -75.370246          STATE                 MAXIMUM
# 10000705             -75.436395          STATE                JUVENILE
#
#              facility_capacity  ... facility_data_source_date  \
# facility_id                     ...
# 10005221                 201.0  ... 2022-01-07 15:27:25+00:00
# 10005223                  30.0  ... 2022-01-07 15:27:25+00:00
# 10003049                1183.0  ... 2022-01-07 15:27:25+00:00
# 10003059                  60.0  ... 2022-01-07 15:27:25+00:00
# 10003047                1522.0  ... 2022-01-07 15:27:25+00:00
# ...                        ...  ...                       ...
# 10003117                1178.0  ... 2022-01-07 15:27:25+00:00
# 10000708                 250.0  ... 2022-01-07 15:27:25+00:00
# 10000706                 248.0  ... 2022-01-07 15:27:25+00:00
# 10000707                1206.0  ... 2022-01-07 15:27:25+00:00
# 10000705                  55.0  ... 2022-01-07 15:27:25+00:00
#
#               facility_data_edit_date monitoring_site_name  \
# facility_id
# 10005221    2022-01-07 15:27:25+00:00             Scranton
# 10005223    2022-01-07 15:27:25+00:00             Scranton
# 10003049    2022-01-07 15:27:25+00:00             Scranton
# 10003059    2022-01-07 15:27:25+00:00             Scranton
# 10003047    2022-01-07 15:27:25+00:00             Scranton
# ...                               ...                  ...
# 10003117    2022-01-07 15:27:25+00:00              Chester
# 10000708    2022-01-07 15:27:25+00:00              SEAFORD
# 10000706    2022-01-07 15:27:25+00:00              SEAFORD
# 10000707    2022-01-07 15:27:25+00:00              SEAFORD
# 10000705    2022-01-07 15:27:25+00:00              KILLENS
#
#             monitoring_site_state monitoring_site_county  \
# facility_id
# 10005221                       PA             LACKAWANNA
# 10005223                       PA             LACKAWANNA
# 10003049                       PA             LACKAWANNA
# 10003059                       PA             LACKAWANNA
# 10003047                       PA             LACKAWANNA
# ...                           ...                    ...
# 10003117                       PA               DELAWARE
# 10000708                       DE                 SUSSEX
# 10000706                       DE                 SUSSEX
# 10000707                       DE                 SUSSEX
# 10000705                       DE                   KENT
#
#             monitoring_site_latitude monitoring_site_longitude  peak_pm25_aqi  \
# facility_id
# 10005221                   41.442800                  -75.6231            385
# 10005223                   41.442800                  -75.6231            385
# 10003049                   41.442800                  -75.6231            385
# 10003059                   41.442800                  -75.6231            385
# 10003047                   41.442800                  -75.6231            385
# ...                              ...                       ...            ...
# 10003117                   39.835600                  -75.3725            438
# 10000708                   38.653900                  -75.6106            223
# 10000706                   38.653900                  -75.6106            223
# 10000707                   38.653900                  -75.6106            223
# 10000705                   38.986672                  -75.5568            243
#
#              mean_pm25_aqi                                           geometry
# facility_id
# 10005221        263.666667  MULTIPOLYGON (((-75.20832 41.54933, -75.20821 ...
# 10005223        263.666667  MULTIPOLYGON (((-75.66103 41.40874, -75.66086 ...
# 10003049        263.666667  MULTIPOLYGON (((-75.64832 41.42327, -75.64821 ...
# 10003059        263.666667  MULTIPOLYGON (((-75.72628 41.31262, -75.72618 ...
# 10003047        263.666667  MULTIPOLYGON (((-75.43174 41.57536, -75.43040 ...
# ...                    ...                                                ...
# 10003117        238.208333  MULTIPOLYGON (((-75.35024 39.85255, -75.35016 ...
# 10000708        186.416667  MULTIPOLYGON (((-75.36911 38.65798, -75.36793 ...
# 10000706        186.416667  MULTIPOLYGON (((-75.37244 38.65862, -75.37211 ...
# 10000707        186.416667  MULTIPOLYGON (((-75.37251 38.66097, -75.36791 ...
# 10000705        189.708333  MULTIPOLYGON (((-75.43712 38.91931, -75.43698 ...
#
# [222 rows x 22 columns]

# %% [markdown]
# Number of facilities above 300:

# %%
joined_data.loc[
    lambda df: df["peak_pm25_aqi"] > 300
]
# Out:
#                                           facility_name  \
# facility_id
# 10005221             WAYNE COUNTY CORRECTIONAL FACILITY
# 10005223                             MINSEC OF SCRANTON
# 10003049                       LACKAWANNA COUNTY PRISON
# 10003059                                  PA CHILD CARE
# 10003047                                    SCI WAYMART
# ...                                                 ...
# 10000733                                  SCI CAMP HILL
# 10003080                           LEHIGH COUNTY PRISON
# 10003081     LEHIGH COUNTY COMMUNITY CORRECTIONS CENTER
# 10003119      DELAWARE COUNTY JUVENILE DETENTION CENTER
# 10003117                                    SCI CHESTER
#
#                     facility_address      facility_city facility_state  \
# facility_id
# 10005221             44 MID-WAYNE DR          HONESDALE             PA
# 10005223               539 LINDEN ST           SCRANTON             PA
# 10003049       1371 N WASHINGTON AVE           SCRANTON             PA
# 10003059              701 SATHERS DR  PITTSTON TOWNSHIP             PA
# 10003047              11 FAIRVIEW DR            WAYMART             PA
# ...                              ...                ...            ...
# 10000733            2500 LISBURN RD.          CAMP HILL             PA
# 10003080                 38 N 4TH ST          ALLENTOWN             PA
# 10003081           1600 RIVERSIDE DR          BETHLEHEM             PA
# 10003119     370 NORTH MIDDLETOWN RD               LIMA             PA
# 10003117          500 EAST FOURTH ST            CHESTER             PA
#
#             facility_zip  facility_latitude  facility_longitude  \
# facility_id
# 10005221           18431          41.548698          -75.208834
# 10005223           18503          41.408550          -75.661082
# 10003049           18509          41.422658          -75.648372
# 10003059           18640          41.312296          -75.725906
# 10003047           18472          41.574452          -75.429367
# ...                  ...                ...                 ...
# 10000733           17001          40.217967          -76.927382
# 10003080           18102          40.604898          -75.466403
# 10003081           18016          40.612469          -75.412656
# 10003119           19037          39.921556          -75.444577
# 10003117           19013          39.851245          -75.351338
#
#              facility_type facility_security_level  facility_capacity  ...  \
# facility_id                                                            ...
# 10005221            COUNTY           NOT AVAILABLE              201.0  ...
# 10005223             LOCAL           NOT AVAILABLE               30.0  ...
# 10003049            COUNTY                 MAXIMUM             1183.0  ...
# 10003059     NOT AVAILABLE                JUVENILE               60.0  ...
# 10003047             STATE                 MAXIMUM             1522.0  ...
# ...                    ...                     ...                ...  ...
# 10000733             STATE           NOT AVAILABLE             3272.0  ...
# 10003080            COUNTY                 MAXIMUM             1270.0  ...
# 10003081            COUNTY                 MINIMUM              400.0  ...
# 10003119            COUNTY                JUVENILE               66.0  ...
# 10003117             STATE                  MEDIUM             1178.0  ...
#
#             facility_data_source_date   facility_data_edit_date  \
# facility_id
# 10005221    2022-01-07 15:27:25+00:00 2022-01-07 15:27:25+00:00
# 10005223    2022-01-07 15:27:25+00:00 2022-01-07 15:27:25+00:00
# 10003049    2022-01-07 15:27:25+00:00 2022-01-07 15:27:25+00:00
# 10003059    2022-01-07 15:27:25+00:00 2022-01-07 15:27:25+00:00
# 10003047    2022-01-07 15:27:25+00:00 2022-01-07 15:27:25+00:00
# ...                               ...                       ...
# 10000733    2022-01-07 15:27:25+00:00 2022-01-07 15:27:25+00:00
# 10003080    2022-01-07 15:27:25+00:00 2022-01-07 15:27:25+00:00
# 10003081    2022-01-07 15:27:25+00:00 2022-01-07 15:27:25+00:00
# 10003119    2022-01-07 15:27:25+00:00 2022-01-07 15:27:25+00:00
# 10003117    2022-01-07 15:27:25+00:00 2022-01-07 15:27:25+00:00
#
#             monitoring_site_name monitoring_site_state monitoring_site_county  \
# facility_id
# 10005221                Scranton                    PA             LACKAWANNA
# 10005223                Scranton                    PA             LACKAWANNA
# 10003049                Scranton                    PA             LACKAWANNA
# 10003059                Scranton                    PA             LACKAWANNA
# 10003047                Scranton                    PA             LACKAWANNA
# ...                          ...                   ...                    ...
# 10000733              Harrisburg                    PA                DAUPHIN
# 10003080               Allentown                    PA                 LEHIGH
# 10003081               Allentown                    PA                 LEHIGH
# 10003119                 Chester                    PA               DELAWARE
# 10003117                 Chester                    PA               DELAWARE
#
#             monitoring_site_latitude monitoring_site_longitude  peak_pm25_aqi  \
# facility_id
# 10005221                   41.442800                -75.623100            385
# 10005223                   41.442800                -75.623100            385
# 10003049                   41.442800                -75.623100            385
# 10003059                   41.442800                -75.623100            385
# 10003047                   41.442800                -75.623100            385
# ...                              ...                       ...            ...
# 10000733                   40.246992                -76.846988            387
# 10003080                   40.611900                -75.432500            449
# 10003081                   40.611900                -75.432500            449
# 10003119                   39.835600                -75.372500            438
# 10003117                   39.835600                -75.372500            438
#
#              mean_pm25_aqi                                           geometry
# facility_id
# 10005221        263.666667  MULTIPOLYGON (((-75.20832 41.54933, -75.20821 ...
# 10005223        263.666667  MULTIPOLYGON (((-75.66103 41.40874, -75.66086 ...
# 10003049        263.666667  MULTIPOLYGON (((-75.64832 41.42327, -75.64821 ...
# 10003059        263.666667  MULTIPOLYGON (((-75.72628 41.31262, -75.72618 ...
# 10003047        263.666667  MULTIPOLYGON (((-75.43174 41.57536, -75.43040 ...
# ...                    ...                                                ...
# 10000733        207.750000  MULTIPOLYGON (((-76.93098 40.21783, -76.92761 ...
# 10003080        283.041667  MULTIPOLYGON (((-75.46685 40.60510, -75.46621 ...
# 10003081        283.041667  MULTIPOLYGON (((-75.41347 40.61299, -75.41285 ...
# 10003119        238.208333  MULTIPOLYGON (((-75.44538 39.92210, -75.44535 ...
# 10003117        238.208333  MULTIPOLYGON (((-75.35024 39.85255, -75.35016 ...
#
# [141 rows x 22 columns]

# %% [markdown]
# Number of sites above 400:

# %%
joined_data.loc[
    lambda df: df["peak_pm25_aqi"] > 400
]
# Out:
#                                           facility_name  \
# facility_id
# 10006642                                ABRAXAS ACADEMY
# 10002270                       BERKS COUNTY JAIL SYSTEM
# 10002271          BERKS COUNTY COMMUNITY REENTRY CENTER
# 10006847                BERKS COUNTY RESIDENTIAL CENTER
# 10000725                       SCHUYLKILL COUNTY PRISON
# ...                                                 ...
# 10006387       HAZEL D. PLANT WOMENS TREATMENT FACILITY
# 10003080                           LEHIGH COUNTY PRISON
# 10003081     LEHIGH COUNTY COMMUNITY CORRECTIONS CENTER
# 10003119      DELAWARE COUNTY JUVENILE DETENTION CENTER
# 10003117                                    SCI CHESTER
#
#                     facility_address facility_city facility_state  \
# facility_id
# 10006642          1000 ACADEMY DRIVE    MORGANTOWN             PA
# 10002270      1287 COUNTY WELFARE RD      LEESPORT             PA
# 10002271      1261 COUNTY WELFARE RD      LEESPORT             PA
# 10006847             1040 BERKS ROAD      LEESPORT             PA
# 10000725            230 SANDERSON ST    POTTSVILLE             PA
# ...                              ...           ...            ...
# 10006387        620 BAYLOR BOULEVARD    NEW CASTLE             DE
# 10003080                 38 N 4TH ST     ALLENTOWN             PA
# 10003081           1600 RIVERSIDE DR     BETHLEHEM             PA
# 10003119     370 NORTH MIDDLETOWN RD          LIMA             PA
# 10003117          500 EAST FOURTH ST       CHESTER             PA
#
#             facility_zip  facility_latitude  facility_longitude facility_type  \
# facility_id
# 10006642           19543          40.191808          -75.916953         STATE
# 10002270           19533          40.385264          -76.020695        COUNTY
# 10002271           19533          40.382898          -76.017713        COUNTY
# 10006847           19533          40.379468          -76.019540        COUNTY
# 10000725           17901          40.688517          -76.199253        COUNTY
# ...                  ...                ...                 ...           ...
# 10006387           19720          39.702451          -75.582935         STATE
# 10003080           18102          40.604898          -75.466403        COUNTY
# 10003081           18016          40.612469          -75.412656        COUNTY
# 10003119           19037          39.921556          -75.444577        COUNTY
# 10003117           19013          39.851245          -75.351338         STATE
#
#             facility_security_level  facility_capacity  ...  \
# facility_id                                             ...
# 10006642                   JUVENILE              156.0  ...
# 10002270              NOT AVAILABLE             1546.0  ...
# 10002271              NOT AVAILABLE             -999.0  ...
# 10006847              NOT AVAILABLE             -999.0  ...
# 10000725              NOT AVAILABLE              277.0  ...
# ...                             ...                ...  ...
# 10006387              NOT AVAILABLE               96.0  ...
# 10003080                    MAXIMUM             1270.0  ...
# 10003081                    MINIMUM              400.0  ...
# 10003119                   JUVENILE               66.0  ...
# 10003117                     MEDIUM             1178.0  ...
#
#             facility_data_source_date   facility_data_edit_date  \
# facility_id
# 10006642    2022-01-07 15:27:25+00:00 2022-01-07 15:27:25+00:00
# 10002270    2022-01-07 15:27:25+00:00 2022-01-07 15:27:25+00:00
# 10002271    2022-01-07 15:27:25+00:00 2022-01-07 15:27:25+00:00
# 10006847    2022-01-07 15:27:25+00:00 2022-01-07 15:27:25+00:00
# 10000725    2022-01-07 15:27:25+00:00 2022-01-07 15:27:25+00:00
# ...                               ...                       ...
# 10006387    2022-01-07 15:27:25+00:00 2022-01-07 15:27:25+00:00
# 10003080    2022-01-07 15:27:25+00:00 2022-01-07 15:27:25+00:00
# 10003081    2022-01-07 15:27:25+00:00 2022-01-07 15:27:25+00:00
# 10003119    2022-01-07 15:27:25+00:00 2022-01-07 15:27:25+00:00
# 10003117    2022-01-07 15:27:25+00:00 2022-01-07 15:27:25+00:00
#
#             monitoring_site_name monitoring_site_state monitoring_site_county  \
# facility_id
# 10006642         Reading Airport                    PA                  BERKS
# 10002270         Reading Airport                    PA                  BERKS
# 10002271         Reading Airport                    PA                  BERKS
# 10006847         Reading Airport                    PA                  BERKS
# 10000725         Reading Airport                    PA                  BERKS
# ...                          ...                   ...                    ...
# 10006387                     MLK                    DE             NEW CASTLE
# 10003080               Allentown                    PA                 LEHIGH
# 10003081               Allentown                    PA                 LEHIGH
# 10003119                 Chester                    PA               DELAWARE
# 10003117                 Chester                    PA               DELAWARE
#
#             monitoring_site_latitude monitoring_site_longitude  peak_pm25_aqi  \
# facility_id
# 10006642                   40.383300                -75.968600            434
# 10002270                   40.383300                -75.968600            434
# 10002271                   40.383300                -75.968600            434
# 10006847                   40.383300                -75.968600            434
# 10000725                   40.383300                -75.968600            434
# ...                              ...                       ...            ...
# 10006387                   39.739444                -75.558056            403
# 10003080                   40.611900                -75.432500            449
# 10003081                   40.611900                -75.432500            449
# 10003119                   39.835600                -75.372500            438
# 10003117                   39.835600                -75.372500            438
#
#              mean_pm25_aqi                                           geometry
# facility_id
# 10006642        251.583333  MULTIPOLYGON (((-75.91828 40.19098, -75.91822 ...
# 10002270        251.583333  MULTIPOLYGON (((-76.02199 40.38624, -76.02124 ...
# 10002271        251.583333  MULTIPOLYGON (((-76.01828 40.38317, -76.01798 ...
# 10006847        251.583333  MULTIPOLYGON (((-76.02031 40.37891, -76.02056 ...
# 10000725        251.583333  MULTIPOLYGON (((-76.19988 40.68868, -76.19886 ...
# ...                    ...                                                ...
# 10006387        225.000000  MULTIPOLYGON (((-75.58326 39.70271, -75.58313 ...
# 10003080        283.041667  MULTIPOLYGON (((-75.46685 40.60510, -75.46621 ...
# 10003081        283.041667  MULTIPOLYGON (((-75.41347 40.61299, -75.41285 ...
# 10003119        238.208333  MULTIPOLYGON (((-75.44538 39.92210, -75.44535 ...
# 10003117        238.208333  MULTIPOLYGON (((-75.35024 39.85255, -75.35016 ...
#
# [88 rows x 22 columns]

# %% [markdown]
# Number of sites above 500:

# %%
joined_data.loc[
    lambda df: df["peak_pm25_aqi"] > 500
]
# Out:
#                                                  facility_name  \
# facility_id
# 10003113           ALTERNATIVE & SPECIAL DETENTION CENTER(ASD)
# 10003114                         PHILADELPHIA DETENTION CENTER
# 10004005           ALBERT C WAGNER YOUTH CORRECTIONAL FACILITY
# 10004002                                       CRAF JONES FARM
# 10004004              GARDEN STATE YOUTH CORRECTIONAL FACILITY
# 10001516                       MID-STATE CORRECTIONAL FACILITY
# 10004003                               NEW JERSEY STATE PRISON
# 10004006           JOHNSTONE JUVENILE MEDIUM SECURITY FACILITY
# 10004007     JOHNSTONE JUVENILE FEMALE SECURE CARE AND INTA...
# 10006598                             ANN KLEIN FORENSIC CENTER
# 10006600               ALBERT ELIAS RESIDENTIAL COMMUNITY HOME
# 10004008                                     FCI FORT DIX CAMP
# 10002301             CENTRAL RECEPTION AND ASSIGNMENT FACILITY
# 10002304                    BURLINGTON COUNTY DETENTION CENTER
# 10000770                                          FCI FORT DIX
# 10004009           BURLINGTON COUNTY JUVENILE DETENTION CENTER
# 10002300                          TRENTON PSYCHIATRIC HOSPITAL
# 10003110         CURRAN- FROMHOLD CORRECTIONAL FACILITY (CFCF)
# 10004000                     MERCER COUNTY CORRECTIONAL CENTER
# 10003112                       RIVERSIDE CORRECTIONAL FACILITY
# 10003115           PHILADELPHIA INDUSTRIAL CORRECTIONAL CENTER
#
#                           facility_address facility_city facility_state  \
# facility_id
# 10003113                     8101 STATE RD  PHILADELPHIA             PA
# 10003114                     8201 STATE RD  PHILADELPHIA             PA
# 10004005                      500 WARD AVE  CHESTERFIELD             NJ
# 10004002                721 BEAR TAVERN RD       TRENTON             NJ
# 10004004                     55 HOGBACK RD    CROSSWICKS             NJ
# 10001516                      866 RANGE RD   WRIGHTSTOWN             NJ
# 10004003                       600 CASS ST       TRENTON             NJ
# 10004006       BURLINGTON ST, P.O. BOX 307    BORDENTOWN             NJ
# 10004007       BURLINGTON ST, P.O. BOX 367    BORDENTOWN             NJ
# 10006598                 STUYVESANT AVENUE  WEST TRENTON             NJ
# 10006600        479 WEST BURLINGTON STREET    BORDENTOWN             NJ
# 10004008      5756 HARTFORD & POINTVILE RD      FORT DIX             NJ
# 10002301            2401 STUYVESANT AVENUE       TRENTON             NJ
# 10002304                       54 GRANT ST   MOUNT HOLLY             NJ
# 10000770      5756 HARTFORD & POINTVILE RD      FORT DIX             NJ
# 10004009     620 PEMBERTON-BROWNS MILLS RD     PEMBERTON             NJ
# 10002300                  100 SULLIVAN WAY  WEST TRENTON             NJ
# 10003110                     7901 STATE RD  PHILADELPHIA             PA
# 10004000                     1750 ROUTE 29  LAMBERTVILLE             NJ
# 10003112                   8151 STATE ROAD  PHILADELPHIA             PA
# 10003115                     8301 STATE RD  PHILADELPHIA             PA
#
#             facility_zip  facility_latitude  facility_longitude facility_type  \
# facility_id
# 10003113           19136          40.029802          -75.015976         LOCAL
# 10003114           19136          40.033064          -75.015325         LOCAL
# 10004005           08515          40.159583          -74.669523         STATE
# 10004002           08628          40.274645          -74.829314         STATE
# 10004004           08515          40.159168          -74.676344         STATE
# 10001516           08562          39.998564          -74.583393         STATE
# 10004003           08608          40.207273          -74.756369         STATE
# 10004006           08505          40.136752          -74.722248         STATE
# 10004007           08505          40.142900          -74.721582         STATE
# 10006598           08628          40.247051          -74.801885         STATE
# 10006600           08505          40.142630          -74.723624         STATE
# 10004008           08640          40.000207          -74.618041       FEDERAL
# 10002301           08628          40.247596          -74.804526         STATE
# 10002304           08060          39.996071          -74.790918        COUNTY
# 10000770           08640          39.999630          -74.614538       FEDERAL
# 10004009           08068          39.968536          -74.640431        COUNTY
# 10002300           08628          40.243863          -74.805877         STATE
# 10003110           19136          40.029723          -75.019756         LOCAL
# 10004000           08530          40.329175          -74.919257        COUNTY
# 10003112           19136          40.029348          -75.017085         LOCAL
# 10003115           19136          40.034679          -75.013566         LOCAL
#
#             facility_security_level  facility_capacity  ...  \
# facility_id                                             ...
# 10003113                    MINIMUM              860.0  ...
# 10003114                    MINIMUM             1677.0  ...
# 10004005                   JUVENILE             1032.0  ...
# 10004002                    MINIMUM             -999.0  ...
# 10004004                   JUVENILE             1168.0  ...
# 10001516                     MEDIUM              696.0  ...
# 10004003                    MAXIMUM             1819.0  ...
# 10004006                   JUVENILE              262.0  ...
# 10004007                   JUVENILE               48.0  ...
# 10006598              NOT AVAILABLE              200.0  ...
# 10006600                   JUVENILE               25.0  ...
# 10004008                    MINIMUM              334.0  ...
# 10002301                    MAXIMUM              691.0  ...
# 10002304              NOT AVAILABLE              625.0  ...
# 10000770                    MINIMUM             4041.0  ...
# 10004009                   JUVENILE             -999.0  ...
# 10002300              NOT AVAILABLE              400.0  ...
# 10003110                      CLOSE             2560.0  ...
# 10004000                    MAXIMUM              880.0  ...
# 10003112                      CLOSE              824.0  ...
# 10003115                      CLOSE             1230.0  ...
#
#             facility_data_source_date   facility_data_edit_date  \
# facility_id
# 10003113    2022-01-07 15:27:25+00:00 2022-01-07 15:27:25+00:00
# 10003114    2022-01-07 15:27:25+00:00 2022-01-07 15:27:25+00:00
# 10004005    2022-01-07 15:27:25+00:00 2022-01-07 15:27:25+00:00
# 10004002    2022-01-07 15:27:25+00:00 2022-01-07 15:27:25+00:00
# 10004004    2022-01-07 15:27:25+00:00 2022-01-07 15:27:25+00:00
# 10001516    2022-01-07 15:27:25+00:00 2022-01-07 15:27:25+00:00
# 10004003    2022-01-07 15:27:25+00:00 2022-01-07 15:27:25+00:00
# 10004006    2022-01-07 15:27:25+00:00 2022-01-07 15:27:25+00:00
# 10004007    2022-01-07 15:27:25+00:00 2022-01-07 15:27:25+00:00
# 10006598    2022-01-07 15:27:25+00:00 2022-01-07 15:27:25+00:00
# 10006600    2022-01-07 15:27:25+00:00 2022-01-07 15:27:25+00:00
# 10004008    2022-01-07 15:27:25+00:00 2022-01-07 15:27:25+00:00
# 10002301    2022-01-07 15:27:25+00:00 2022-01-07 15:27:25+00:00
# 10002304    2022-01-07 15:27:25+00:00 2022-01-07 15:27:25+00:00
# 10000770    2022-01-07 15:27:25+00:00 2022-01-07 15:27:25+00:00
# 10004009    2022-01-07 15:27:25+00:00 2022-01-07 15:27:25+00:00
# 10002300    2022-01-07 15:27:25+00:00 2022-01-07 15:27:25+00:00
# 10003110    2022-01-07 15:27:25+00:00 2022-01-07 15:27:25+00:00
# 10004000    2022-01-07 15:27:25+00:00 2022-01-07 15:27:25+00:00
# 10003112    2022-01-07 15:27:25+00:00 2022-01-07 15:27:25+00:00
# 10003115    2022-01-07 15:27:25+00:00 2022-01-07 15:27:25+00:00
#
#             monitoring_site_name monitoring_site_state monitoring_site_county  \
# facility_id
# 10003113                     TOR                    PA           PHILADELPHIA
# 10003114                     TOR                    PA           PHILADELPHIA
# 10004005                     TOR                    PA           PHILADELPHIA
# 10004002                     TOR                    PA           PHILADELPHIA
# 10004004                     TOR                    PA           PHILADELPHIA
# 10001516                     TOR                    PA           PHILADELPHIA
# 10004003                     TOR                    PA           PHILADELPHIA
# 10004006                     TOR                    PA           PHILADELPHIA
# 10004007                     TOR                    PA           PHILADELPHIA
# 10006598                     TOR                    PA           PHILADELPHIA
# 10006600                     TOR                    PA           PHILADELPHIA
# 10004008                     TOR                    PA           PHILADELPHIA
# 10002301                     TOR                    PA           PHILADELPHIA
# 10002304                     TOR                    PA           PHILADELPHIA
# 10000770                     TOR                    PA           PHILADELPHIA
# 10004009                     TOR                    PA           PHILADELPHIA
# 10002300                     TOR                    PA           PHILADELPHIA
# 10003110                     TOR                    PA           PHILADELPHIA
# 10004000                     TOR                    PA           PHILADELPHIA
# 10003112                     TOR                    PA           PHILADELPHIA
# 10003115                     TOR                    PA           PHILADELPHIA
#
#             monitoring_site_latitude monitoring_site_longitude  peak_pm25_aqi  \
# facility_id
# 10003113                   40.054171                -74.985166            501
# 10003114                   40.054171                -74.985166            501
# 10004005                   40.054171                -74.985166            501
# 10004002                   40.054171                -74.985166            501
# 10004004                   40.054171                -74.985166            501
# 10001516                   40.054171                -74.985166            501
# 10004003                   40.054171                -74.985166            501
# 10004006                   40.054171                -74.985166            501
# 10004007                   40.054171                -74.985166            501
# 10006598                   40.054171                -74.985166            501
# 10006600                   40.054171                -74.985166            501
# 10004008                   40.054171                -74.985166            501
# 10002301                   40.054171                -74.985166            501
# 10002304                   40.054171                -74.985166            501
# 10000770                   40.054171                -74.985166            501
# 10004009                   40.054171                -74.985166            501
# 10002300                   40.054171                -74.985166            501
# 10003110                   40.054171                -74.985166            501
# 10004000                   40.054171                -74.985166            501
# 10003112                   40.054171                -74.985166            501
# 10003115                   40.054171                -74.985166            501
#
#              mean_pm25_aqi                                           geometry
# facility_id
# 10003113           278.125  MULTIPOLYGON (((-75.01688 40.03051, -75.01692 ...
# 10003114           278.125  MULTIPOLYGON (((-75.01505 40.03410, -75.01506 ...
# 10004005           278.125  MULTIPOLYGON (((-74.67112 40.16118, -74.67039 ...
# 10004002           278.125  MULTIPOLYGON (((-74.83027 40.27456, -74.82893 ...
# 10004004           278.125  MULTIPOLYGON (((-74.67780 40.16136, -74.67763 ...
# 10001516           278.125  MULTIPOLYGON (((-74.58353 39.99979, -74.58210 ...
# 10004003           278.125  MULTIPOLYGON (((-74.75761 40.20849, -74.75753 ...
# 10004006           278.125  MULTIPOLYGON (((-74.72350 40.13794, -74.72309 ...
# 10004007           278.125  MULTIPOLYGON (((-74.72421 40.14374, -74.72349 ...
# 10006598           278.125  MULTIPOLYGON (((-74.80296 40.24742, -74.80299 ...
# 10006600           278.125  MULTIPOLYGON (((-74.72418 40.14267, -74.72335 ...
# 10004008           278.125  MULTIPOLYGON (((-74.61815 40.00037, -74.61773 ...
# 10002301           278.125  MULTIPOLYGON (((-74.80620 40.24727, -74.80443 ...
# 10002304           278.125  MULTIPOLYGON (((-74.79161 39.99611, -74.79108 ...
# 10000770           278.125  MULTIPOLYGON (((-74.62359 39.99892, -74.62181 ...
# 10004009           278.125  MULTIPOLYGON (((-74.64007 39.96888, -74.64008 ...
# 10002300           278.125  MULTIPOLYGON (((-74.80506 40.24514, -74.80406 ...
# 10003110           278.125  MULTIPOLYGON (((-75.02106 40.03112, -75.02032 ...
# 10004000           278.125  MULTIPOLYGON (((-74.91995 40.32970, -74.91997 ...
# 10003112           278.125  MULTIPOLYGON (((-75.01796 40.02929, -75.01679 ...
# 10003115           278.125  MULTIPOLYGON (((-75.01309 40.03574, -75.01280 ...
#
# [21 rows x 22 columns]

# %% [markdown]
# Write to files:

# %%
joined_data.loc[:, :"mean_pm25_aqi"].to_csv("../data/processed/pm25_aqi_by_facility.csv")

# %%
joined_data.to_file("../data/processed/pm25_aqi_by_facility.geojson")
