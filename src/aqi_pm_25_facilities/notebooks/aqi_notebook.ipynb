# %%
import math

import geopandas as gpd
import pandas as pd
import requests

# %% [markdown]
# Monitoring site documentation: https://docs.airnowapi.org/docs/MonitoringSiteFactSheet.pdf

# %%
monitoring_site_col_names = [
    "AQSID", "parameter_name", "site_code", "site_name", "status",
    "agency_id", "agency_name", "epa_region", "latitude", "longitude",
    "elevation", "gmt_offset", "country_code", "msa_code", "msa_name",
    "state_code", "state_name", "county_code", "county_name"
]

# %%
monitoring_sites = pd.read_csv(
    "../data/source/monitoring_site_locations.dat", 
    sep="|", 
    encoding="latin",
)
monitoring_sites.head()
# Out:
#    060670006  PM10  0006  Arden Arcade - Del Paso Manor  Active  CA1  \
# 0  060670006   NO2  0006  Arden Arcade - Del Paso Manor  Active  CA1
# 1  060670006    WD  0006  Arden Arcade - Del Paso Manor  Active  CA1
# 2  060670006   SO2  0006  Arden Arcade - Del Paso Manor  Active  CA1
# 3  060670006    BC  0006  Arden Arcade - Del Paso Manor  Active  CA1
# 4  060670006  RHUM  0006  Arden Arcade - Del Paso Manor  Active  CA1
#
#    Sacramento Metro. AQMD  R9  38.613804  -121.368007  ...  Unnamed: 13  \
# 0  Sacramento Metro. AQMD  R9  38.613804  -121.368007  ...          NaN
# 1  Sacramento Metro. AQMD  R9  38.613804  -121.368007  ...          NaN
# 2  Sacramento Metro. AQMD  R9  38.613804  -121.368007  ...          NaN
# 3  Sacramento Metro. AQMD  R9  38.613804  -121.368007  ...          NaN
# 4  Sacramento Metro. AQMD  R9  38.613804  -121.368007  ...          NaN
#
#    Unnamed: 14    40900   Sacramento--Arden-Arcade--Roseville, CA   06  CA  \
# 0          NaN  40900.0   Sacramento--Arden-Arcade--Roseville, CA   06  CA
# 1          NaN  40900.0   Sacramento--Arden-Arcade--Roseville, CA   06  CA
# 2          NaN  40900.0   Sacramento--Arden-Arcade--Roseville, CA   06  CA
# 3          NaN  40900.0   Sacramento--Arden-Arcade--Roseville, CA   06  CA
# 4          NaN  40900.0   Sacramento--Arden-Arcade--Roseville, CA   06  CA
#
#    067  SACRAMENTO Unnamed: 21 Unnamed: 22
# 0  067  SACRAMENTO         NaN         NaN
# 1  067  SACRAMENTO         NaN         NaN
# 2  067  SACRAMENTO         NaN         NaN
# 3  067  SACRAMENTO         NaN         NaN
# 4  067  SACRAMENTO         NaN         NaN
#
# [5 rows x 23 columns]

# %% [markdown]
# It's unclear why pandas added four extra empty columns, but we should get rid of them and add the correct column names. This code drops the first row, but it's not relevant for our purposes.

# %%
monitoring_sites = monitoring_sites.drop(
    columns=[
        "Unnamed: 13", "Unnamed: 14",
        "Unnamed: 21", "Unnamed: 22"
    ]
)
monitoring_sites.columns = monitoring_site_col_names
monitoring_sites.head()
# Out:
#        AQSID parameter_name site_code                      site_name  status  \
# 0  060670006            NO2      0006  Arden Arcade - Del Paso Manor  Active
# 1  060670006             WD      0006  Arden Arcade - Del Paso Manor  Active
# 2  060670006            SO2      0006  Arden Arcade - Del Paso Manor  Active
# 3  060670006             BC      0006  Arden Arcade - Del Paso Manor  Active
# 4  060670006           RHUM      0006  Arden Arcade - Del Paso Manor  Active
#
#   agency_id             agency_name epa_region   latitude   longitude  \
# 0       CA1  Sacramento Metro. AQMD         R9  38.613804 -121.368007
# 1       CA1  Sacramento Metro. AQMD         R9  38.613804 -121.368007
# 2       CA1  Sacramento Metro. AQMD         R9  38.613804 -121.368007
# 3       CA1  Sacramento Metro. AQMD         R9  38.613804 -121.368007
# 4       CA1  Sacramento Metro. AQMD         R9  38.613804 -121.368007
#
#    elevation  gmt_offset country_code  msa_code  \
# 0       25.3        -8.0           US   40900.0
# 1       25.3        -8.0           US   40900.0
# 2       25.3        -8.0           US   40900.0
# 3       25.3        -8.0           US   40900.0
# 4       25.3        -8.0           US   40900.0
#
#                                     msa_name state_code state_name  \
# 0   Sacramento--Arden-Arcade--Roseville, CA          06         CA
# 1   Sacramento--Arden-Arcade--Roseville, CA          06         CA
# 2   Sacramento--Arden-Arcade--Roseville, CA          06         CA
# 3   Sacramento--Arden-Arcade--Roseville, CA          06         CA
# 4   Sacramento--Arden-Arcade--Roseville, CA          06         CA
#
#   county_code county_name
# 0         067  SACRAMENTO
# 1         067  SACRAMENTO
# 2         067  SACRAMENTO
# 3         067  SACRAMENTO
# 4         067  SACRAMENTO

# %% [markdown]
# Filter sites to states of interest and their neighbors:

# %%
monitoring_sites.loc[
    lambda df: (
        (
            df["state_name"]
            .isin(
                [
                    "MA", "CT", "VT", "NY", "NJ", 
                    "PA", "OH", "MD", "DE", "WV",
                ]
            )
        )
        & (df["parameter_name"] == "PM2.5")
    )
]
# Out:
#               AQSID parameter_name site_code         site_name  status  \
# 14        360850111          PM2.5      0111       Fresh Kills  Active
# 21        390030009          PM2.5      0009              Lima  Active
# 385       250250042          PM2.5      0042  Boston - Roxbury  Active
# 445       250095005          PM2.5      5005         Haverhill  Active
# 494       420070014          PM2.5      0014      Beaver Falls  Active
# ...             ...            ...       ...               ...     ...
# 18521  840340292002          PM2.5      2002        Toms River  Active
# 19105     420150011          PM2.5      0011           Towanda  Active
# 19128     360551007          PM2.5      1007         Rochester  Active
# 19140     360671015          PM2.5      1015        E Syracuse  Active
# 19150     500210002          PM2.5      0002           Rutland  Active
#
#       agency_id                                      agency_name epa_region  \
# 14          NY1     New York Dept. of Environmental Conservation         R2
# 21          OH1                                    Ohio EPA-DAPC         R5
# 385         MA1  Massachusetts Dept. of Environmental Protection         R1
# 445         MA1  Massachusetts Dept. of Environmental Protection         R1
# 494         PA1   Pennsylvania Dept. of Environmental Protection         R3
# ...         ...                                              ...        ...
# 18521       NJ1     New Jersey Dept. of Environmental Protection         R2
# 19105       PA1   Pennsylvania Dept. of Environmental Protection         R3
# 19128       NY1     New York Dept. of Environmental Conservation         R2
# 19140       NY1     New York Dept. of Environmental Conservation         R2
# 19150       VT1           Vermont Air Quality & Climate Division         R1
#
#         latitude  longitude  elevation  gmt_offset country_code  msa_code  \
# 14     40.580200 -74.199400        0.0        -5.0           US   35620.0
# 21     40.771000 -84.053900      275.1        -5.0           US   30620.0
# 385    42.329399 -71.082497        0.0        -5.0           US   14460.0
# 445    42.770800 -71.102800        0.0        -5.0           US   14460.0
# 494    40.747799 -80.316704        0.0        -5.0           US   38300.0
# ...          ...        ...        ...         ...          ...       ...
# 18521  39.994908 -74.170447        8.8        -5.0           US   35620.0
# 19105  41.705226 -76.512726      340.1        -5.0           US       NaN
# 19128  43.146100 -77.548100        0.0        -5.0           US   40380.0
# 19140  43.052800 -76.059700        0.0        -5.0           US   45060.0
# 19150  43.608528 -72.982460      171.1        -5.0           US   40860.0
#
#                                                 msa_name state_code  \
# 14      New York-Northern New Jersey-Long Island, NY-...         36
# 21                                             Lima, OH          39
# 385                      Boston-Cambridge-Quincy, MA-NH          25
# 445                      Boston-Cambridge-Quincy, MA-NH          25
# 494                                      Pittsburgh, PA          42
# ...                                                  ...        ...
# 18521   New York-Northern New Jersey-Long Island, NY-...         34
# 19105                                                NaN         42
# 19128                                     Rochester, NY          36
# 19140                                      Syracuse, NY          36
# 19150                                       Rutland, VT          50
#
#       state_name county_code county_name
# 14            NY         085    RICHMOND
# 21            OH         003       ALLEN
# 385           MA         025     SUFFOLK
# 445           MA         009       ESSEX
# 494           PA         007      BEAVER
# ...          ...         ...         ...
# 18521         NJ         029       OCEAN
# 19105         PA         015    BRADFORD
# 19128         NY         055      MONROE
# 19140         NY         067    ONONDAGA
# 19150         VT         021     RUTLAND
#
# [194 rows x 19 columns]

# %% [markdown]
# Read in hourly observations:

# %%
hourly_obs = pd.read_csv("../data/source/hourly_obs.csv", na_values="-999")
hourly_obs.head()
# Out:
#             site    site_id    0    1    2    3    4    5    6    7  ...   14  \
# 0  CHARLOTTETOWN  000020104  0.7  0.6  0.4  0.6  0.8  1.1  1.2  1.1  ...  1.2
# 1  CHARLOTTETOWN  000020104    G    G    G    G    G    G    G    G  ...    G
# 2     WELLINGTON  000020301  3.3  1.5  0.9  1.2  0.7  0.9  1.7  1.4  ...  2.4
# 3     WELLINGTON  000020301    G    G    G    G    G    G    G    G  ...    G
# 4    SOUTHAMPTON  000020401  1.6  1.3  1.0  0.9  0.9  1.5  1.5  1.5  ...  2.4
#
#     15   16   17   18   19   20   21   22   23
# 0  1.7  2.5  3.3  3.2  3.6  4.3  3.9  3.7  3.6
# 1    G    G    G    G    G    G    G    G    G
# 2  2.9  2.9  3.0  3.3  3.7  3.7  3.6  3.5  3.8
# 3    G    G    G    G    G    G    G    G    G
# 4  4.0  4.7  5.8  7.3  7.4  7.0  6.4  6.7  5.6
#
# [5 rows x 26 columns]

# %% [markdown]
# Drop the non-data rows:

# %%
hourly_obs = hourly_obs.iloc[::2]

# %% [markdown]
# Calculate the peak observation at each site:

# %%
hourly_obs["peak"] = hourly_obs.loc[:, '0':'23'].T.applymap(float).max()

# %% [markdown]
# Calculate the average observation at each site:

# %%
hourly_obs["average"] = hourly_obs.loc[:, '0':'23'].T.applymap(float).mean()

# %%
hourly_obs.head()
# Out:
#                   site    site_id    0    1    2    3    4    5    6    7  \
# 0        CHARLOTTETOWN  000020104  0.7  0.6  0.4  0.6  0.8  1.1  1.2  1.1
# 2           WELLINGTON  000020301  3.3  1.5  0.9  1.2  0.7  0.9  1.7  1.4
# 4          SOUTHAMPTON  000020401  1.6  1.3  1.0  0.9  0.9  1.5  1.5  1.5
# 6  JOHNSTON BUILDING -  000030113  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 8           Lake Major  000030120  3.2  3.0  2.9  3.6  3.2  2.5  1.6  2.5
#
#    ...   16   17   18   19   20   21    22    23  peak   average
# 0  ...  2.5  3.3  3.2  3.6  4.3  3.9   3.7   3.6   4.3  1.970833
# 2  ...  2.9  3.0  3.3  3.7  3.7  3.6   3.5   3.8   3.8  2.200000
# 4  ...  4.7  5.8  7.3  7.4  7.0  6.4   6.7   5.6   7.4  3.200000
# 6  ...  NaN  NaN  NaN  NaN  NaN  NaN   NaN   NaN   NaN       NaN
# 8  ...  NaN  NaN  NaN  9.3  9.9  9.4  10.0  10.3  10.3  5.230000
#
# [5 rows x 28 columns]

# %% [markdown]
# Combine the lat/long data with the peak AQI data:

# %%
peak_site_data = (
    monitoring_sites
    .merge(
        hourly_obs,
        left_on="AQSID",
        right_on="site_id",
    )
    .set_index("site_id")
)[["site_name", "state_name", "county_name", "latitude", "longitude", "peak", "average"]]
peak_site_data.head()
# Out:
#                                site_name state_name county_name   latitude  \
# site_id
# 060670006  Arden Arcade - Del Paso Manor         CA  SACRAMENTO  38.613804
# 060670006  Arden Arcade - Del Paso Manor         CA  SACRAMENTO  38.613804
# 060670006  Arden Arcade - Del Paso Manor         CA  SACRAMENTO  38.613804
# 060670006  Arden Arcade - Del Paso Manor         CA  SACRAMENTO  38.613804
# 060670006  Arden Arcade - Del Paso Manor         CA  SACRAMENTO  38.613804
#
#             longitude  peak   average
# site_id
# 060670006 -121.368007   7.0  4.666667
# 060670006 -121.368007   7.0  4.666667
# 060670006 -121.368007   7.0  4.666667
# 060670006 -121.368007   7.0  4.666667
# 060670006 -121.368007   7.0  4.666667

# %% [markdown]
# Load facility data:

# %%
facilities = gpd.read_file("../data/source/prison_boundaries.geojson")
facilities.head()
# Out:
#    FID FACILITYID                                      NAME  \
# 0    1   10002798   MIDLAND COUNTY CENTRAL DETENTION CENTER
# 1    2   10002796  BARBARA CULVER JUVENILE DETENTION CENTER
# 2    3   10002836                   SAN JACINTO COUNTY JAIL
# 3    4   10003033               YELLOW MEDICINE COUNTY JAIL
# 4    5   10006288     NMJC THIEF RIVER FALLS SATELLITE HOME
#
#                 ADDRESS               CITY STATE    ZIP  ZIP4       TELEPHONE  \
# 0         400 S MAIN ST            MIDLAND    TX  79701  -999  (432) 688-4745
# 1      3800 N LAMESA RD            MIDLAND    TX  79701  -999  (432) 688-4541
# 2        75 W CEDAR AVE         COLDSPRING    TX  77331  -999  (936) 653-4367
# 3        415 9TH AVENUE      GRANITE FALLS    MN  56241  -999  (320) 313-3049
# 4  118 N. SPRUCE AVENUE  THIEF RIVER FALLS    MN  56701  -999  (218) 681-3484
#
#      TYPE  ... CAPACITY  SHAPE_Leng                                GlobalID  \
# 0  COUNTY  ...    498.0    0.007275  {86DE7B8A-37D4-4D99-984B-D70D2B8C474F}
# 1  COUNTY  ...     24.0    0.004645  {1C1E4C11-3209-4E90-85C7-957AE58CEB3C}
# 2  COUNTY  ...    144.0    0.002327  {0764FA0C-E415-4F31-95AB-751C895E6CCF}
# 3  COUNTY  ...     36.0    0.002272  {9A789E0C-3A99-44D7-A17C-3F0C940DC400}
# 4   LOCAL  ...      5.0    0.000644  {A4CD4104-0496-45C8-B09B-FC49557098D0}
#
#                CreationDate        Creator                  EditDate  \
# 0 2022-01-07 15:27:25+00:00  HostedByHIFLD 2022-01-07 15:27:25+00:00
# 1 2022-01-07 15:27:25+00:00  HostedByHIFLD 2022-01-07 15:27:25+00:00
# 2 2022-01-07 15:27:25+00:00  HostedByHIFLD 2022-01-07 15:27:25+00:00
# 3 2022-01-07 15:27:25+00:00  HostedByHIFLD 2022-01-07 15:27:25+00:00
# 4 2022-01-07 15:27:25+00:00  HostedByHIFLD 2022-01-07 15:27:25+00:00
#
#           Editor SHAPE_Length    SHAPE_Area  \
# 0  HostedByHIFLD     0.007275  2.579058e-06
# 1  HostedByHIFLD     0.004645  9.897645e-07
# 2  HostedByHIFLD     0.002327  3.075715e-07
# 3  HostedByHIFLD     0.002272  1.900107e-07
# 4  HostedByHIFLD     0.000644  2.457488e-08
#
#                                             geometry
# 0  MULTIPOLYGON (((-102.07687 31.99381, -102.0744...
# 1  MULTIPOLYGON (((-102.07655 32.03859, -102.0762...
# 2  MULTIPOLYGON (((-95.12992 30.59128, -95.12955 ...
# 3  MULTIPOLYGON (((-95.54458 44.80976, -95.54434 ...
# 4  MULTIPOLYGON (((-96.16240 48.11734, -96.16221 ...
#
# [5 rows x 33 columns]

# %% [markdown]
# Filter to open facilities in our states of interest:

# %%
facilities_midatlantic = (
    facilities.loc[
        lambda df: (
            df["STATE"].isin(["NY", "NJ", "PA", "DE"])
            & df["STATUS"].str.match("OPEN")
        )
    ]
    .copy()
    .drop_duplicates()
)

# %% [markdown]
# Find the centroid of each facility (we can ignore this warning, because we're just trying to find the nearest monitoring site, and this won't really matter for that):

# %%
facilities_midatlantic["centroid"] = (
    facilities_midatlantic["geometry"]
    .centroid
)
# Out:
# /tmp/ipykernel_53888/1775512362.py:3: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   .centroid

# %%
def distance(point, lat, long):
    """Calculate distance using the Haversine formula."""
    lat_1 = math.radians(point.y)
    lat_2 = math.radians(lat)
    lon_1 = math.radians(point.x)
    lon_2 = math.radians(long)
    d_lat = lat_1 - lat_2
    d_lon = lon_1 - lon_2
    alpha = (
        math.sin(d_lat / 2)**2 
        + math.cos(lat_1) 
        * math.cos(lat_2) 
        * math.sin(d_lon / 2)**2
    )
    radius = 3958.8  # radius of earth in miles
    return (
        2
        * radius
        * math.atan2(math.sqrt(alpha), math.sqrt(1 - alpha))
    )

# %% [markdown]
# Find the nearest monitoring site for each facility (using a horrifically inefficient algorithm, but the data is small enough that we don't really mind):

# %%
def nearest_site(point, site_data):
    return site_data.assign(
        dist=site_data.apply(
            lambda x: distance(
                point,
                x["latitude"],
                x["longitude"],
            ),
            axis=1
        )
    ).loc[lambda df: df["dist"] == df["dist"].min()].index[0]

# %%
facilities_midatlantic["nearest_site"] = (
    facilities_midatlantic["centroid"]
    .map(lambda x: nearest_site(x, peak_site_data.dropna()))
)

# %%
joined_data = (
    facilities_midatlantic
    .merge(
        peak_site_data.reset_index(),
        left_on="nearest_site",
        right_on="site_id",
    )
    .rename(
        columns={
            "FACILITYID": "facility_id",
            "NAME": "facility_name",
            "ADDRESS": "facility_address",
            "CITY": "facility_city",
            "STATE": "facility_state",
            "ZIP": "facility_zip",
            "TYPE": "facility_type",
            "SECURELVL": "facility_security_level",
            "CAPACITY": "facility_capacity",
            "STATUS": "facility_status",
            "SOURCE": "facility_data_source",
            "CreationDate": "facility_data_source_date",
            "EditDate": "facility_data_edit_date",
            "site_name": "monitoring_site_name",
            "state_name": "monitoring_site_state",
            "county_name": "monitoring_site_county",
            "latitude": "monitoring_site_latitude",
            "longitude": "monitoring_site_longitude",
            "peak": "peak_pm25_aqi",
            "average": "mean_pm25_aqi",
        }
    )
    .drop_duplicates()
    .set_index("facility_id")
).assign(
    facility_latitude=lambda df: df["centroid"].map(lambda x: x.y),
    facility_longitude=lambda df: df["centroid"].map(lambda x: x.x),
)[
    [
        "facility_name", "facility_address", "facility_city",
        "facility_state", "facility_zip", "facility_latitude",
        "facility_longitude", "facility_type",
        "facility_security_level", "facility_capacity",
        "facility_status", "facility_data_source_date",
        "facility_data_edit_date", "monitoring_site_name",
        "monitoring_site_state", "monitoring_site_county",
        "monitoring_site_latitude", "monitoring_site_longitude",
        "peak_pm25_aqi", "mean_pm25_aqi", "geometry",
    ]
]

# %% [markdown]
# Number of facilities above 200:

# %%
joined_data.loc[
    lambda df: df["peak_pm25_aqi"] > 200
]
# Out:
#                                                  facility_name  \
# facility_id
# 10005221                    WAYNE COUNTY CORRECTIONAL FACILITY
# 10005223                                    MINSEC OF SCRANTON
# 10003049                              LACKAWANNA COUNTY PRISON
# 10003059                                         PA CHILD CARE
# 10003047                                           SCI WAYMART
# ...                                                        ...
# 10000702     DIVISION OF YOUTH REHABILITATIVE SERVICES RESI...
# 10000701                  PLUMMER COMMUNITY CORRECTIONS CENTER
# 10002260               BAYLOR WOMEN'S CORRECTIONAL INSTITUTION
# 10005219                    NEW CASTLE COUNTY DETENTION CENTER
# 10006387              HAZEL D. PLANT WOMENS TREATMENT FACILITY
#
#                   facility_address      facility_city facility_state  \
# facility_id
# 10005221           44 MID-WAYNE DR          HONESDALE             PA
# 10005223             539 LINDEN ST           SCRANTON             PA
# 10003049     1371 N WASHINGTON AVE           SCRANTON             PA
# 10003059            701 SATHERS DR  PITTSTON TOWNSHIP             PA
# 10003047            11 FAIRVIEW DR            WAYMART             PA
# ...                            ...                ...            ...
# 10000702         1825 FAULKLAND RD         WILMINGTON             DE
# 10000701               38 TODDS LN         WILMINGTON             DE
# 10002260           660 BAYLOR BLVD         NEW CASTLE             DE
# 10005219             963 CENTRE RD         WILMINGTON             DE
# 10006387      620 BAYLOR BOULEVARD         NEW CASTLE             DE
#
#             facility_zip  facility_latitude  facility_longitude  \
# facility_id
# 10005221           18431          41.548698          -75.208834
# 10005223           18503          41.408550          -75.661082
# 10003049           18509          41.422658          -75.648372
# 10003059           18640          41.312296          -75.725906
# 10003047           18472          41.574452          -75.429367
# ...                  ...                ...                 ...
# 10000702           19805          39.750162          -75.612572
# 10000701           19802          39.756645          -75.529044
# 10002260           19720          39.703932          -75.581258
# 10005219           19805          39.754230          -75.610557
# 10006387           19720          39.702451          -75.582935
#
#              facility_type facility_security_level  facility_capacity  ...  \
# facility_id                                                            ...
# 10005221            COUNTY           NOT AVAILABLE              201.0  ...
# 10005223             LOCAL           NOT AVAILABLE               30.0  ...
# 10003049            COUNTY                 MAXIMUM             1183.0  ...
# 10003059     NOT AVAILABLE                JUVENILE               60.0  ...
# 10003047             STATE                 MAXIMUM             1522.0  ...
# ...                    ...                     ...                ...  ...
# 10000702             STATE                JUVENILE               45.0  ...
# 10000701             STATE           NOT AVAILABLE              246.0  ...
# 10002260             STATE                 MAXIMUM              320.0  ...
# 10005219             STATE                JUVENILE               64.0  ...
# 10006387             STATE           NOT AVAILABLE               96.0  ...
#
#             facility_data_source_date   facility_data_edit_date  \
# facility_id
# 10005221    2022-01-07 15:27:25+00:00 2022-01-07 15:27:25+00:00
# 10005223    2022-01-07 15:27:25+00:00 2022-01-07 15:27:25+00:00
# 10003049    2022-01-07 15:27:25+00:00 2022-01-07 15:27:25+00:00
# 10003059    2022-01-07 15:27:25+00:00 2022-01-07 15:27:25+00:00
# 10003047    2022-01-07 15:27:25+00:00 2022-01-07 15:27:25+00:00
# ...                               ...                       ...
# 10000702    2022-01-07 15:27:25+00:00 2022-01-07 15:27:25+00:00
# 10000701    2022-01-07 15:27:25+00:00 2022-01-07 15:27:25+00:00
# 10002260    2022-01-07 15:27:25+00:00 2022-01-07 15:27:25+00:00
# 10005219    2022-01-07 15:27:25+00:00 2022-01-07 15:27:25+00:00
# 10006387    2022-01-07 15:27:25+00:00 2022-01-07 15:27:25+00:00
#
#             monitoring_site_name monitoring_site_state monitoring_site_county  \
# facility_id
# 10005221                Scranton                    PA             LACKAWANNA
# 10005223                Scranton                    PA             LACKAWANNA
# 10003049                Scranton                    PA             LACKAWANNA
# 10003059                Scranton                    PA             LACKAWANNA
# 10003047                Scranton                    PA             LACKAWANNA
# ...                          ...                   ...                    ...
# 10000702                     MLK                    DE             NEW CASTLE
# 10000701                     MLK                    DE             NEW CASTLE
# 10002260                     MLK                    DE             NEW CASTLE
# 10005219                     MLK                    DE             NEW CASTLE
# 10006387                     MLK                    DE             NEW CASTLE
#
#             monitoring_site_latitude  monitoring_site_longitude  \
# facility_id
# 10005221                   41.442800                 -75.623100
# 10005223                   41.442800                 -75.623100
# 10003049                   41.442800                 -75.623100
# 10003059                   41.442800                 -75.623100
# 10003047                   41.442800                 -75.623100
# ...                              ...                        ...
# 10000702                   39.739444                 -75.558056
# 10000701                   39.739444                 -75.558056
# 10002260                   39.739444                 -75.558056
# 10005219                   39.739444                 -75.558056
# 10006387                   39.739444                 -75.558056
#
#              peak_pm25_aqi  mean_pm25_aqi  \
# facility_id
# 10005221             357.5     215.245833
# 10005223             357.5     215.245833
# 10003049             357.5     215.245833
# 10003059             357.5     215.245833
# 10003047             357.5     215.245833
# ...                    ...            ...
# 10000702             380.3     169.687500
# 10000701             380.3     169.687500
# 10002260             380.3     169.687500
# 10005219             380.3     169.687500
# 10006387             380.3     169.687500
#
#                                                       geometry
# facility_id
# 10005221     MULTIPOLYGON (((-75.20832 41.54933, -75.20821 ...
# 10005223     MULTIPOLYGON (((-75.66103 41.40874, -75.66086 ...
# 10003049     MULTIPOLYGON (((-75.64832 41.42327, -75.64821 ...
# 10003059     MULTIPOLYGON (((-75.72628 41.31262, -75.72618 ...
# 10003047     MULTIPOLYGON (((-75.43174 41.57536, -75.43040 ...
# ...                                                        ...
# 10000702     MULTIPOLYGON (((-75.61186 39.75069, -75.61194 ...
# 10000701     MULTIPOLYGON (((-75.52850 39.75648, -75.52904 ...
# 10002260     MULTIPOLYGON (((-75.58220 39.70471, -75.58213 ...
# 10005219     MULTIPOLYGON (((-75.61104 39.75479, -75.61070 ...
# 10006387     MULTIPOLYGON (((-75.58326 39.70271, -75.58313 ...
#
# [266 rows x 21 columns]

# %% [markdown]
# Number of facilities above 300:

# %%
joined_data.loc[
    lambda df: df["peak_pm25_aqi"] > 300
]
# Out:
#                                                  facility_name  \
# facility_id
# 10005221                    WAYNE COUNTY CORRECTIONAL FACILITY
# 10005223                                    MINSEC OF SCRANTON
# 10003049                              LACKAWANNA COUNTY PRISON
# 10003059                                         PA CHILD CARE
# 10003047                                           SCI WAYMART
# ...                                                        ...
# 10000702     DIVISION OF YOUTH REHABILITATIVE SERVICES RESI...
# 10000701                  PLUMMER COMMUNITY CORRECTIONS CENTER
# 10002260               BAYLOR WOMEN'S CORRECTIONAL INSTITUTION
# 10005219                    NEW CASTLE COUNTY DETENTION CENTER
# 10006387              HAZEL D. PLANT WOMENS TREATMENT FACILITY
#
#                   facility_address      facility_city facility_state  \
# facility_id
# 10005221           44 MID-WAYNE DR          HONESDALE             PA
# 10005223             539 LINDEN ST           SCRANTON             PA
# 10003049     1371 N WASHINGTON AVE           SCRANTON             PA
# 10003059            701 SATHERS DR  PITTSTON TOWNSHIP             PA
# 10003047            11 FAIRVIEW DR            WAYMART             PA
# ...                            ...                ...            ...
# 10000702         1825 FAULKLAND RD         WILMINGTON             DE
# 10000701               38 TODDS LN         WILMINGTON             DE
# 10002260           660 BAYLOR BLVD         NEW CASTLE             DE
# 10005219             963 CENTRE RD         WILMINGTON             DE
# 10006387      620 BAYLOR BOULEVARD         NEW CASTLE             DE
#
#             facility_zip  facility_latitude  facility_longitude  \
# facility_id
# 10005221           18431          41.548698          -75.208834
# 10005223           18503          41.408550          -75.661082
# 10003049           18509          41.422658          -75.648372
# 10003059           18640          41.312296          -75.725906
# 10003047           18472          41.574452          -75.429367
# ...                  ...                ...                 ...
# 10000702           19805          39.750162          -75.612572
# 10000701           19802          39.756645          -75.529044
# 10002260           19720          39.703932          -75.581258
# 10005219           19805          39.754230          -75.610557
# 10006387           19720          39.702451          -75.582935
#
#              facility_type facility_security_level  facility_capacity  ...  \
# facility_id                                                            ...
# 10005221            COUNTY           NOT AVAILABLE              201.0  ...
# 10005223             LOCAL           NOT AVAILABLE               30.0  ...
# 10003049            COUNTY                 MAXIMUM             1183.0  ...
# 10003059     NOT AVAILABLE                JUVENILE               60.0  ...
# 10003047             STATE                 MAXIMUM             1522.0  ...
# ...                    ...                     ...                ...  ...
# 10000702             STATE                JUVENILE               45.0  ...
# 10000701             STATE           NOT AVAILABLE              246.0  ...
# 10002260             STATE                 MAXIMUM              320.0  ...
# 10005219             STATE                JUVENILE               64.0  ...
# 10006387             STATE           NOT AVAILABLE               96.0  ...
#
#             facility_data_source_date   facility_data_edit_date  \
# facility_id
# 10005221    2022-01-07 15:27:25+00:00 2022-01-07 15:27:25+00:00
# 10005223    2022-01-07 15:27:25+00:00 2022-01-07 15:27:25+00:00
# 10003049    2022-01-07 15:27:25+00:00 2022-01-07 15:27:25+00:00
# 10003059    2022-01-07 15:27:25+00:00 2022-01-07 15:27:25+00:00
# 10003047    2022-01-07 15:27:25+00:00 2022-01-07 15:27:25+00:00
# ...                               ...                       ...
# 10000702    2022-01-07 15:27:25+00:00 2022-01-07 15:27:25+00:00
# 10000701    2022-01-07 15:27:25+00:00 2022-01-07 15:27:25+00:00
# 10002260    2022-01-07 15:27:25+00:00 2022-01-07 15:27:25+00:00
# 10005219    2022-01-07 15:27:25+00:00 2022-01-07 15:27:25+00:00
# 10006387    2022-01-07 15:27:25+00:00 2022-01-07 15:27:25+00:00
#
#             monitoring_site_name monitoring_site_state monitoring_site_county  \
# facility_id
# 10005221                Scranton                    PA             LACKAWANNA
# 10005223                Scranton                    PA             LACKAWANNA
# 10003049                Scranton                    PA             LACKAWANNA
# 10003059                Scranton                    PA             LACKAWANNA
# 10003047                Scranton                    PA             LACKAWANNA
# ...                          ...                   ...                    ...
# 10000702                     MLK                    DE             NEW CASTLE
# 10000701                     MLK                    DE             NEW CASTLE
# 10002260                     MLK                    DE             NEW CASTLE
# 10005219                     MLK                    DE             NEW CASTLE
# 10006387                     MLK                    DE             NEW CASTLE
#
#             monitoring_site_latitude  monitoring_site_longitude  \
# facility_id
# 10005221                   41.442800                 -75.623100
# 10005223                   41.442800                 -75.623100
# 10003049                   41.442800                 -75.623100
# 10003059                   41.442800                 -75.623100
# 10003047                   41.442800                 -75.623100
# ...                              ...                        ...
# 10000702                   39.739444                 -75.558056
# 10000701                   39.739444                 -75.558056
# 10002260                   39.739444                 -75.558056
# 10005219                   39.739444                 -75.558056
# 10006387                   39.739444                 -75.558056
#
#              peak_pm25_aqi  mean_pm25_aqi  \
# facility_id
# 10005221             357.5     215.245833
# 10005223             357.5     215.245833
# 10003049             357.5     215.245833
# 10003059             357.5     215.245833
# 10003047             357.5     215.245833
# ...                    ...            ...
# 10000702             380.3     169.687500
# 10000701             380.3     169.687500
# 10002260             380.3     169.687500
# 10005219             380.3     169.687500
# 10006387             380.3     169.687500
#
#                                                       geometry
# facility_id
# 10005221     MULTIPOLYGON (((-75.20832 41.54933, -75.20821 ...
# 10005223     MULTIPOLYGON (((-75.66103 41.40874, -75.66086 ...
# 10003049     MULTIPOLYGON (((-75.64832 41.42327, -75.64821 ...
# 10003059     MULTIPOLYGON (((-75.72628 41.31262, -75.72618 ...
# 10003047     MULTIPOLYGON (((-75.43174 41.57536, -75.43040 ...
# ...                                                        ...
# 10000702     MULTIPOLYGON (((-75.61186 39.75069, -75.61194 ...
# 10000701     MULTIPOLYGON (((-75.52850 39.75648, -75.52904 ...
# 10002260     MULTIPOLYGON (((-75.58220 39.70471, -75.58213 ...
# 10005219     MULTIPOLYGON (((-75.61104 39.75479, -75.61070 ...
# 10006387     MULTIPOLYGON (((-75.58326 39.70271, -75.58313 ...
#
# [170 rows x 21 columns]

# %% [markdown]
# Number of sites above 400:

# %%
joined_data.loc[
    lambda df: df["peak_pm25_aqi"] > 400
]
# Out:
#                                             facility_name  \
# facility_id
# 10006642                                  ABRAXAS ACADEMY
# 10002270                         BERKS COUNTY JAIL SYSTEM
# 10002271            BERKS COUNTY COMMUNITY REENTRY CENTER
# 10006847                  BERKS COUNTY RESIDENTIAL CENTER
# 10000725                         SCHUYLKILL COUNTY PRISON
# ...                                                   ...
# 10005816     SAINT JOHNS - RICHMOND HILL DETENTION CENTER
# 10005814                         QUEENS DETENTION COMPLEX
# 10002308               SALEM COUNTY CORRECTIONAL FACILITY
# 10003119        DELAWARE COUNTY JUVENILE DETENTION CENTER
# 10003117                                      SCI CHESTER
#
#                     facility_address  facility_city facility_state  \
# facility_id
# 10006642          1000 ACADEMY DRIVE     MORGANTOWN             PA
# 10002270      1287 COUNTY WELFARE RD       LEESPORT             PA
# 10002271      1261 COUNTY WELFARE RD       LEESPORT             PA
# 10006847             1040 BERKS ROAD       LEESPORT             PA
# 10000725            230 SANDERSON ST     POTTSVILLE             PA
# ...                              ...            ...            ...
# 10005816         130-20 107TH AVENUE  RICHMOND HILL             NY
# 10005814          126-01 82ND AVENUE    KEW GARDENS             NY
# 10002308             125 CEMETERY RD      WOODSTOWN             NJ
# 10003119     370 NORTH MIDDLETOWN RD           LIMA             PA
# 10003117          500 EAST FOURTH ST        CHESTER             PA
#
#             facility_zip  facility_latitude  facility_longitude facility_type  \
# facility_id
# 10006642           19543          40.191808          -75.916953         STATE
# 10002270           19533          40.385264          -76.020695        COUNTY
# 10002271           19533          40.382898          -76.017713        COUNTY
# 10006847           19533          40.379468          -76.019540        COUNTY
# 10000725           17901          40.688517          -76.199253        COUNTY
# ...                  ...                ...                 ...           ...
# 10005816           11419          40.686968          -73.813415         LOCAL
# 10005814           11415          40.712991          -73.825486         LOCAL
# 10002308           08098          39.629881          -75.357215        COUNTY
# 10003119           19037          39.921556          -75.444577        COUNTY
# 10003117           19013          39.851245          -75.351338         STATE
#
#             facility_security_level  facility_capacity  ...  \
# facility_id                                             ...
# 10006642                   JUVENILE              156.0  ...
# 10002270              NOT AVAILABLE             1546.0  ...
# 10002271              NOT AVAILABLE             -999.0  ...
# 10006847              NOT AVAILABLE             -999.0  ...
# 10000725              NOT AVAILABLE              277.0  ...
# ...                             ...                ...  ...
# 10005816                   JUVENILE               12.0  ...
# 10005814              NOT AVAILABLE             -999.0  ...
# 10002308                    MAXIMUM              464.0  ...
# 10003119                   JUVENILE               66.0  ...
# 10003117                     MEDIUM             1178.0  ...
#
#             facility_data_source_date   facility_data_edit_date  \
# facility_id
# 10006642    2022-01-07 15:27:25+00:00 2022-01-07 15:27:25+00:00
# 10002270    2022-01-07 15:27:25+00:00 2022-01-07 15:27:25+00:00
# 10002271    2022-01-07 15:27:25+00:00 2022-01-07 15:27:25+00:00
# 10006847    2022-01-07 15:27:25+00:00 2022-01-07 15:27:25+00:00
# 10000725    2022-01-07 15:27:25+00:00 2022-01-07 15:27:25+00:00
# ...                               ...                       ...
# 10005816    2022-01-07 15:27:25+00:00 2022-01-07 15:27:25+00:00
# 10005814    2022-01-07 15:27:25+00:00 2022-01-07 15:27:25+00:00
# 10002308    2022-01-07 15:27:25+00:00 2022-01-07 15:27:25+00:00
# 10003119    2022-01-07 15:27:25+00:00 2022-01-07 15:27:25+00:00
# 10003117    2022-01-07 15:27:25+00:00 2022-01-07 15:27:25+00:00
#
#                     monitoring_site_name monitoring_site_state  \
# facility_id
# 10006642                 Reading Airport                    PA
# 10002270                 Reading Airport                    PA
# 10002271                 Reading Airport                    PA
# 10006847                 Reading Airport                    PA
# 10000725                 Reading Airport                    PA
# ...                                  ...                   ...
# 10005816                          Queens                    NY
# 10005814                          Queens                    NY
# 10002308     RIVER ROAD PARK; BELLEFONTE                    DE
# 10003119                         Chester                    PA
# 10003117                         Chester                    PA
#
#             monitoring_site_county monitoring_site_latitude  \
# facility_id
# 10006642                     BERKS                  40.3833
# 10002270                     BERKS                  40.3833
# 10002271                     BERKS                  40.3833
# 10006847                     BERKS                  40.3833
# 10000725                     BERKS                  40.3833
# ...                            ...                      ...
# 10005816                    QUEENS                  40.7375
# 10005814                    QUEENS                  40.7375
# 10002308                NEW CASTLE                  39.7611
# 10003119                  DELAWARE                  39.8356
# 10003117                  DELAWARE                  39.8356
#
#              monitoring_site_longitude  peak_pm25_aqi  mean_pm25_aqi  \
# facility_id
# 10006642                      -75.9686          418.3     204.383333
# 10002270                      -75.9686          418.3     204.383333
# 10002271                      -75.9686          418.3     204.383333
# 10006847                      -75.9686          418.3     204.383333
# 10000725                      -75.9686          418.3     204.383333
# ...                                ...            ...            ...
# 10005816                      -73.8244          412.0     200.358333
# 10005814                      -73.8244          412.0     200.358333
# 10002308                      -75.4919          428.1     193.000000
# 10003119                      -75.3725          423.0     186.008333
# 10003117                      -75.3725          423.0     186.008333
#
#                                                       geometry
# facility_id
# 10006642     MULTIPOLYGON (((-75.91828 40.19098, -75.91822 ...
# 10002270     MULTIPOLYGON (((-76.02199 40.38624, -76.02124 ...
# 10002271     MULTIPOLYGON (((-76.01828 40.38317, -76.01798 ...
# 10006847     MULTIPOLYGON (((-76.02031 40.37891, -76.02056 ...
# 10000725     MULTIPOLYGON (((-76.19988 40.68868, -76.19886 ...
# ...                                                        ...
# 10005816     MULTIPOLYGON (((-73.81356 40.68709, -73.81340 ...
# 10005814     MULTIPOLYGON (((-73.82582 40.71362, -73.82561 ...
# 10002308     MULTIPOLYGON (((-75.35853 39.63020, -75.35808 ...
# 10003119     MULTIPOLYGON (((-75.44538 39.92210, -75.44535 ...
# 10003117     MULTIPOLYGON (((-75.35024 39.85255, -75.35016 ...
#
# [70 rows x 21 columns]

# %% [markdown]
# Number of sites above 500:

# %%
joined_data.loc[
    lambda df: df["peak_pm25_aqi"] > 500
]
# Out:
#                                              facility_name facility_address  \
# facility_id
# 10003113       ALTERNATIVE & SPECIAL DETENTION CENTER(ASD)    8101 STATE RD
# 10003114                     PHILADELPHIA DETENTION CENTER    8201 STATE RD
# 10002304                BURLINGTON COUNTY DETENTION CENTER      54 GRANT ST
# 10003110     CURRAN- FROMHOLD CORRECTIONAL FACILITY (CFCF)    7901 STATE RD
# 10003112                   RIVERSIDE CORRECTIONAL FACILITY  8151 STATE ROAD
# 10003115       PHILADELPHIA INDUSTRIAL CORRECTIONAL CENTER    8301 STATE RD
#
#             facility_city facility_state facility_zip  facility_latitude  \
# facility_id
# 10003113     PHILADELPHIA             PA        19136          40.029802
# 10003114     PHILADELPHIA             PA        19136          40.033064
# 10002304      MOUNT HOLLY             NJ        08060          39.996071
# 10003110     PHILADELPHIA             PA        19136          40.029723
# 10003112     PHILADELPHIA             PA        19136          40.029348
# 10003115     PHILADELPHIA             PA        19136          40.034679
#
#              facility_longitude facility_type facility_security_level  \
# facility_id
# 10003113             -75.015976         LOCAL                 MINIMUM
# 10003114             -75.015325         LOCAL                 MINIMUM
# 10002304             -74.790918        COUNTY           NOT AVAILABLE
# 10003110             -75.019756         LOCAL                   CLOSE
# 10003112             -75.017085         LOCAL                   CLOSE
# 10003115             -75.013566         LOCAL                   CLOSE
#
#              facility_capacity  ... facility_data_source_date  \
# facility_id                     ...
# 10003113                 860.0  ... 2022-01-07 15:27:25+00:00
# 10003114                1677.0  ... 2022-01-07 15:27:25+00:00
# 10002304                 625.0  ... 2022-01-07 15:27:25+00:00
# 10003110                2560.0  ... 2022-01-07 15:27:25+00:00
# 10003112                 824.0  ... 2022-01-07 15:27:25+00:00
# 10003115                1230.0  ... 2022-01-07 15:27:25+00:00
#
#               facility_data_edit_date monitoring_site_name  \
# facility_id
# 10003113    2022-01-07 15:27:25+00:00                  TOR
# 10003114    2022-01-07 15:27:25+00:00                  TOR
# 10002304    2022-01-07 15:27:25+00:00                  TOR
# 10003110    2022-01-07 15:27:25+00:00                  TOR
# 10003112    2022-01-07 15:27:25+00:00                  TOR
# 10003115    2022-01-07 15:27:25+00:00                  TOR
#
#             monitoring_site_state monitoring_site_county  \
# facility_id
# 10003113                       PA           PHILADELPHIA
# 10003114                       PA           PHILADELPHIA
# 10002304                       PA           PHILADELPHIA
# 10003110                       PA           PHILADELPHIA
# 10003112                       PA           PHILADELPHIA
# 10003115                       PA           PHILADELPHIA
#
#             monitoring_site_latitude  monitoring_site_longitude  \
# facility_id
# 10003113                   40.054171                 -74.985166
# 10003114                   40.054171                 -74.985166
# 10002304                   40.054171                 -74.985166
# 10003110                   40.054171                 -74.985166
# 10003112                   40.054171                 -74.985166
# 10003115                   40.054171                 -74.985166
#
#              peak_pm25_aqi  mean_pm25_aqi  \
# facility_id
# 10003113             510.1     235.716667
# 10003114             510.1     235.716667
# 10002304             510.1     235.716667
# 10003110             510.1     235.716667
# 10003112             510.1     235.716667
# 10003115             510.1     235.716667
#
#                                                       geometry
# facility_id
# 10003113     MULTIPOLYGON (((-75.01688 40.03051, -75.01692 ...
# 10003114     MULTIPOLYGON (((-75.01505 40.03410, -75.01506 ...
# 10002304     MULTIPOLYGON (((-74.79161 39.99611, -74.79108 ...
# 10003110     MULTIPOLYGON (((-75.02106 40.03112, -75.02032 ...
# 10003112     MULTIPOLYGON (((-75.01796 40.02929, -75.01679 ...
# 10003115     MULTIPOLYGON (((-75.01309 40.03574, -75.01280 ...
#
# [6 rows x 21 columns]

# %% [markdown]
# Write to files:

# %%
joined_data.loc[:, :"mean_pm25_aqi"].to_csv("../data/processed/pm25_aqi_by_facility.csv")

# %%
joined_data.to_file("../data/processed/pm25_aqi_by_facility.geojson")
